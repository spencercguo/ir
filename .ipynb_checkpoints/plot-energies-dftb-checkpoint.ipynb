# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('dftb-h2o-run-clean.ener', mode='r') as f:
    f.readline()
    ke = []
    pe = []
    tot = []
    temps = []
    while(True):
        line = f.readline()
        entries = line.split()
        ke.append(float(entries[2]))
        pe.append(float(entries[4]))
        tot.append(float(entries[5]))
        temps.append(float(entries[3]))
# Out:
#          0            0.000000         0.545800624       300.000000000      -522.112011310      -521.565735663         0.000000000
#
# ['0', '0.000000', '0.545800624', '300.000000000', '-522.112011310', '-521.565735663', '0.000000000']
#          1            0.500000         0.539597822       296.590621608      -522.105669000      -521.565580149         3.160770936
#
# ['1', '0.500000', '0.539597822', '296.590621608', '-522.105669000', '-521.565580149', '3.160770936']
#          2            1.000000         0.540375065       297.017834271      -522.106478546      -521.565596527         1.128739010
#
# ['2', '1.000000', '0.540375065', '297.017834271', '-522.106478546', '-521.565596527', '1.128739010']
#          3            1.500000         0.547994768       301.206013840      -522.114295989      -521.565778220         1.157080176
#
# ['3', '1.500000', '0.547994768', '301.206013840', '-522.114295989', '-521.565778220', '1.157080176']
#          4            2.000000         0.559812835       307.701829022      -522.126402408      -521.566050237         1.187583176
#
# ['4', '2.000000', '0.559812835', '307.701829022', '-522.126402408', '-521.566050237', '1.187583176']
#          5            2.500000         0.571691408       314.230901696      -522.138542040      -521.566294605         1.215695127
#
# ['5', '2.500000', '0.571691408', '314.230901696', '-522.138542040', '-521.566294605', '1.215695127']
#          6            3.000000         0.579833308       318.706107617      -522.146822413      -521.566416077         1.205147167
#
# ['6', '3.000000', '0.579833308', '318.706107617', '-522.146822413', '-521.566416077', '1.205147167']
#          7            3.500000         0.582284240       320.053265326      -522.149274169      -521.566399726         1.217189633
#
# ['7', '3.500000', '0.582284240', '320.053265326', '-522.149274169', '-521.566399726', '1.217189633']
#          8            4.000000         0.579234309       318.376866744      -522.146127165      -521.566285469         1.211976623
#
# ['8', '4.000000', '0.579234309', '318.376866744', '-522.146127165', '-521.566285469', '1.211976623']
#          9            4.500000         0.572636887       314.750585655      -522.139356239      -521.566094904         1.232817784
#
# ['9', '4.500000', '0.572636887', '314.750585655', '-522.139356239', '-521.566094904', '1.232817784']
